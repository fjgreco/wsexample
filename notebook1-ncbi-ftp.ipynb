# %% [markdown]
# # notebook1-ncbi-ftp

# %% [raw]
# !pip install wget

# %% [raw]
# wslib.download_file("contacts_fjgreco_us_ibm_com.csv")

# %% [raw]
# help(wslib.upload_file)

# %% [raw]
# help(wslib.save_data)

# %% [raw]
# help(wslib.get_connected_data)

# %%
from ibm_watson_studio_lib import access_project_or_space
wslib = access_project_or_space()

# %%
import pandas as pd
import json

# %% [markdown]
# ## Review project's connected data assets

# %%
ncbi_credentials = wslib.get_connection("ncbi")

ncbi_credentials
# Out:
# {'port': '21',
#  'host': 'ftp.ncbi.nih.gov',
#  'connection_mode': 'basic',
#  'username': 'anonymous',
#  '.': {'name': 'ncbi',
#   'description': '',
#   'asset_id': '0d95880f-3c3e-44d4-bf8d-cd98787f3c38',
#   'asset_type': 'connection',
#   'personal_credentials': True}}

# %%
wslib.list_connected_data()
# Out:
# [{'name': 'refseq-genbank.csv',
#   'description': 'ncbi : bioproject/refseq-genbank.csv',
#   'asset_id': 'a7bc469f-82f3-466f-91cf-ef8391af1401',
#   'asset_type': 'data_asset',
#   'tags': ['connected-data']}]

# %%
z=wslib.get_connected_data('refseq-genbank.csv')

print(json.dumps(z,indent=2))
# Out:
# {
#   "port": "21",
#   "host": "ftp.ncbi.nih.gov",
#   "connection_mode": "basic",
#   "username": "anonymous",
#   "datapath": "bioproject/refseq-genbank.csv",
#   ".": {
#     "name": "refseq-genbank.csv",
#     "description": "ncbi : bioproject/refseq-genbank.csv",
#     "asset_id": "a7bc469f-82f3-466f-91cf-ef8391af1401",
#     "asset_type": "data_asset",
#     "asset_state": "available",
#     "tags": [
#       "connected-data"
#     ],
#     "connection": {
#       "name": "ncbi",
#       "description": "",
#       "asset_id": "0d95880f-3c3e-44d4-bf8d-cd98787f3c38",
#       "asset_type": "connection",
#       "personal_credentials": true
#     }
#   }
# }

# %% [markdown]
# ## Pull from FTP site using project asset information

# %%
import ftplib

def setupFTP(x,cwd='.',listd=True):
   
    ftp = ftplib.FTP()

    ftp.connect(x['host'])

    ftp.login(x['username'])

    ftp.cwd(cwd)

    if listd:
        ftp.retrlines("LIST")
    return ftp

def getFTPFile(ftp,source,target,quit=True):
    localfile = open(target, 'wb')
    ftp.retrbinary('RETR ' + source, localfile.write, 1024)
    localfile.close()

    if quit:
        print(ftp.quit())
        
def getFTPList(ftp,listd=True):
    data = []

    ftp.dir(data.append)

    if listd:
        for line in data:
            print ("-", line)
            
    return data
        
    
def ftp_quit(ftp):
    try:
        ftp.quit()
    except:
        print("Already quit")
        
def downloadConnectedData(source,target):
    try:
        x=wslib.get_connected_data(source)
        
        print(json.dumps(x,indent=2))

        print(x['host'], x['username'],x['datapath'])

        ftp=setupFTP(x)

        getFTPFile(ftp,x['datapath'],target)
    except:
        print('error')
        ftp_quit(ftp)

# %% [markdown]
# ## Download  asset from FTP site

# %%
downloadConnectedData("refseq-genbank.csv","refseq-genbank_local.csv")
# Out:
# {
#   "port": "21",
#   "host": "ftp.ncbi.nih.gov",
#   "connection_mode": "basic",
#   "username": "anonymous",
#   "datapath": "bioproject/refseq-genbank.csv",
#   ".": {
#     "name": "refseq-genbank.csv",
#     "description": "ncbi : bioproject/refseq-genbank.csv",
#     "asset_id": "a7bc469f-82f3-466f-91cf-ef8391af1401",
#     "asset_type": "data_asset",
#     "asset_state": "available",
#     "tags": [
#       "connected-data"
#     ],
#     "connection": {
#       "name": "ncbi",
#       "description": "",
#       "asset_id": "0d95880f-3c3e-44d4-bf8d-cd98787f3c38",
#       "asset_type": "connection",
#       "personal_credentials": true
#     }
#   }
# }
# ftp.ncbi.nih.gov anonymous bioproject/refseq-genbank.csv
# dr-xr-xr-x   4 ftp      anonymous     4096 Mar 27 02:48 1000genomes
# -r--r--r--   1 ftp      anonymous 10737418240 Sep 18  2019 10GB
# -r--r--r--   1 ftp      anonymous 1073741824 Sep 18  2019 1GB
# -r--r--r--   1 ftp      anonymous 53687091200 Sep 18  2019 50GB
# -r--r--r--   1 ftp      anonymous 5368709120 Sep 18  2019 5GB
# -r--r--r--   1 ftp      anonymous     2037 Sep 13  2019 README.ftp
# dr-xr-xr-x 1073741824 ftp      anonymous       40 Mar  9 13:27 ReferenceSamples
# dr-xr-xr-x   8 ftp      anonymous     4096 Feb  8 03:48 SampleData
# lr--r--r--   1 ftp      anonymous       29 Sep 13  2019 asn1-converters -> toolbox/ncbi_tools/converters
# dr-xr-xr-x  12 ftp      anonymous   188416 Feb  8 03:48 bigwig
# dr-xr-xr-x   5 ftp      anonymous     4096 Mar 27 15:10 bioproject
# dr-xr-xr-x   2 ftp      anonymous     4096 Mar 27 12:05 biosample
# dr-xr-xr-x  13 ftp      anonymous     4096 Mar 27 02:48 blast
# dr-xr-xr-x   3 ftp      anonymous     4096 Sep 13  2004 cgap
# dr-xr-xr-x   4 ftp      anonymous     4096 Oct  3  2014 cn3d
# dr-xr-xr-x   2 ftp      anonymous    28672 Mar 27 02:48 comparative-genome-viewer
# dr-xr-xr-x  38 ftp      anonymous     4096 Feb  8 03:48 dbgap
# dr-xr-xr-x   2 ftp      anonymous     4096 Sep 21  2017 diffexpIR-notebook
# dr-xr-xr-x  12 ftp      anonymous     4096 Jul 18  2013 entrez
# dr-xr-xr-x   7 ftp      anonymous     4096 Feb  8 03:48 epigenomics
# dr-xr-xr-x   4 ftp      anonymous     4096 Sep 19  2017 eqtl
# dr-xr-xr-x   6 ftp      anonymous     4096 Aug  4  2006 fa2htgs
# -r--r--r--   1 ftp      anonymous     3262 Sep 13  2019 favicon.ico
# -r--r--r--   1 ftp      anonymous      106 Feb 16 13:24 fufuter.html
# dr-xr-xr-x  13 ftp      anonymous   376832 Mar 27 02:48 genbank
# dr-xr-xr-x   6 ftp      anonymous     4096 Feb  8 03:48 gene
# dr-xr-xr-x  15 ftp      anonymous    49152 Mar 27 02:48 genomes
# dr-xr-xr-x 1073741824 ftp      anonymous        0 Mar 27 13:21 geo
# dr-xr-xr-x   4 ftp      anonymous     4096 Mar 27 02:48 giab
# dr-xr-xr-x  25 ftp      anonymous     4096 Sep 20  2011 hapmap
# dr-xr-xr-x  12 ftp      anonymous     4096 Mar 21 21:24 hmm
# dr-xr-xr-x  15 ftp      anonymous     4096 Nov 27 21:23 mmdb
# dr-xr-xr-x   7 ftp      anonymous   184320 Mar 27 02:48 ncbi-asn1
# dr-xr-xr-x   2 ftp      anonymous        6 Sep 13  2019 nist-immsa
# dr-xr-xr-x   3 ftp      anonymous    12288 Sep  1  2021 osiris
# dr-xr-xr-x   9 ftp      anonymous     4096 Mar 27 02:48 pathogen
# dr-xr-xr-x 171 ftp      anonymous     8192 Oct 19 23:53 pub
# dr-xr-xr-x  22 ftp      anonymous     8192 Mar  7 14:03 pubchem
# dr-xr-xr-x   3 ftp      anonymous     4096 Apr 19  2013 pubchem-scratch
# dr-xr-xr-x  28 ftp      anonymous     4096 Dec 13 14:48 pubmed
# dr-xr-xr-x   4 ftp      anonymous     4096 Feb  8 03:48 rapt
# dr-xr-xr-x 1073741824 ftp      anonymous       40 Mar  9 13:27 refsam
# dr-xr-xr-x  22 ftp      anonymous     4096 Mar 11 19:30 refseq
# dr-xr-xr-x  57 ftp      anonymous     4096 Feb  8 03:48 repository
# -r--r--r--   1 ftp      anonymous       26 Sep 13  2019 robots.txt
# dr-xr-xr-x   3 ftp      anonymous     4096 Mar 27 02:48 seqc
# dr-xr-xr-x   3 ftp      anonymous     4096 Jan 26  2021 sequin
# dr-xr-xr-x   4 ftp      anonymous     4096 Jun 23  2016 sky-cgh
# dr-xr-xr-x  11 ftp      anonymous     4096 Mar 27 02:48 snp
# dr-xr-xr-x  23 ftp      anonymous     4096 Mar 27 02:48 sra
# dr-xr-xr-x   2 ftp      anonymous     4096 Sep 29  2004 tech-reports
# dr-xr-xr-x  11 ftp      anonymous     4096 Jul 25  2013 toolbox
# dr-xr-xr-x   8 ftp      anonymous     4096 Sep 19  2021 tpa
# dr-xr-xr-x   5 ftp      anonymous     4096 Aug  9  2016 variation
# 221 Goodbye.

# %% [raw]
# ftp_quit(ftp)

# %% [markdown]
# ### List local storage contents

# %%
# !ls -al
# Out:
# total 248
# drwxr-x---. 3 1000690000 wscommon  4096 Mar 27 19:02 .
# drwxrwx---. 1 wsuser     wsbuild   4096 Mar 27 15:51 ..
# -rw-rw----. 1 1000690000 wscommon 34231 Mar 27 16:32 contacts_fjgreco_us_ibm_com.csv
# -rw-rw----. 1 1000690000 wscommon 93506 Mar 27 17:20 refseq-genbank.csv
# -rw-rw----. 1 1000690000 wscommon 93506 Mar 27 19:02 refseq-genbank_local.csv
# drwxr-x---. 2 1000690000 wscommon  4096 Mar 27 15:50 .virtual_documents

# %% [markdown]
# ## View recently downloaded file in pandas

# %%
pd.read_csv("refseq-genbank_local.csv")
# Out:
#       Refseq accn Genbank accn                   Organism name    TaxID
# 0        PRJNA116   PRJNA10719            Arabidopsis thaliana     3702
# 1        PRJNA116   PRJNA11796            Arabidopsis thaliana     3702
# 2        PRJNA116   PRJNA13191            Arabidopsis thaliana     3702
# 3        PRJNA122   PRJNA12269     Oryza sativa Japonica Group    39947
# 4        PRJNA122    PRJDB1747     Oryza sativa Japonica Group    39947
# ...           ...          ...                             ...      ...
# 1714  PRJNA756971  PRJNA682572        Prionailurus bengalensis    37029
# 1715  PRJNA758027    PRJDB3949            Aspergillus udagawae    91492
# 1716  PRJNA758049    PRJDB7449  Aspergillus pseudoviridinutans  1517512
# 1717  PRJNA759178  PRJNA597580                  Colletes gigas   935657
# 1718  PRJNA759270  PRJNA736740              Venturia canescens    32260
#
# [1719 rows x 4 columns]

# %% [raw]
# import itc_utils.flight_service as itcfs
#
# readClient = itcfs.get_flight_client()
#
# nb_data_request = {
#     'data_name': """refseq-genbank_local.csv""",
#     'interaction_properties': {
#         #'row_limit': 500
#     }
# }
#
# flightInfo = itcfs.get_flight_info(readClient, nb_data_request=nb_data_request)
#
# data_df_1 = itcfs.read_pandas_and_concat(readClient, flightInfo)
# data_df_1.head(10)

# %% [markdown]
# ### List Project locally stored data assets

# %%
# !ls /project_data/data_asset
# Out:
# contacts_fjgreco_us_ibm_com.csv

# %% [markdown]
# ### List project data assets including connected assets

# %%
wslib.assets.list_assets('data_asset')
# Out:
# [{'name': 'contacts_fjgreco_us_ibm_com.csv',
#   'description': '',
#   'asset_id': 'fa0b7995-55bf-4530-9cc6-6b24f8837848',
#   'asset_type': 'data_asset',
#   'tags': []},
#  {'name': 'refseq-genbank.csv',
#   'description': 'ncbi : bioproject/refseq-genbank.csv',
#   'asset_id': 'a7bc469f-82f3-466f-91cf-ef8391af1401',
#   'asset_type': 'data_asset',
#   'tags': ['connected-data']}]

# %% [markdown]
# ### Upload locally saved file to project asset storage

# %%
wslib.upload_file("refseq-genbank_local.csv")
# Out:
# {'name': 'refseq-genbank_local.csv',
#  'asset_type': 'data_asset',
#  'asset_id': '8a0b7b12-e040-4fb0-bf5a-d08c0b2e458f',
#  'attachment_id': '3482b97b-3e83-43d5-8ad4-29bae3fc1814',
#  'filepath': 'refseq-genbank_local.csv',
#  'data_size': None,
#  'mime': 'text/csv',
#  'summary': ['created file in storage', 'created asset', 'created attachment'],
#  'input_file_copied': True}

# %% [markdown]
# ### List project data assets including connected assets and recently uploaded assets

# %%
wslib.assets.list_assets('data_asset')
# Out:
# [{'name': 'refseq-genbank.csv',
#   'description': 'ncbi : bioproject/refseq-genbank.csv',
#   'asset_id': 'a7bc469f-82f3-466f-91cf-ef8391af1401',
#   'asset_type': 'data_asset',
#   'tags': ['connected-data']},
#  {'name': 'refseq-genbank_local.csv',
#   'description': '',
#   'asset_id': '8a0b7b12-e040-4fb0-bf5a-d08c0b2e458f',
#   'asset_type': 'data_asset',
#   'tags': []},
#  {'name': 'contacts_fjgreco_us_ibm_com.csv',
#   'description': '',
#   'asset_id': 'fa0b7995-55bf-4530-9cc6-6b24f8837848',
#   'asset_type': 'data_asset',
#   'tags': []}]
